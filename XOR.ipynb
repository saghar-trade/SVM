# %% [markdown]
# <a href="https://colab.research.google.com/github/saghar-trade/SVM/blob/main/XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from mlxtend.plotting import plot_decision_regions

# %%
xx, yy = np.meshgrid(np.linspace(-3, 3, 50), np.linspace(-3, 3, 50))

# %%
rng = np.random.RandomState(0)
X = rng.randn(300, 2)

# %%
y = np.array(np.logical_xor(X[:, 0] > 0, X[:, 1] > 0), dtype=int)

# %%
model = SVC(kernel='rbf', gamma='auto', C=0.5)
model.fit(X, y)
# Out:
# SVC(C=0.5, gamma='auto')

# %%
plt.figure(figsize=(8, 6))
plot_decision_regions(X, y, clf=model, legend=2)
plt.title("SVM Decision Boundary on XOR Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

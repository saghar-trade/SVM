# %% [markdown]
# <a href="https://colab.research.google.com/github/saghar-trade/SVM/blob/main/make_circle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from sklearn.svm import SVC
from mlxtend.plotting import plot_decision_regions

# %%
X, y = make_circles(n_samples=200, factor=0.4, noise=0.1, random_state=42)

# %%
model = SVC(kernel='rbf', C=1.0, gamma='scale')
model.fit(X, y)
# Out:
# SVC()

# %%
plt.figure(figsize=(8, 6))
plot_decision_regions(X=X, y=y, clf=model, legend=2)

plt.title('SVM Decision Boundary with make_circles')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/saghar-trade/SVM/blob/main/make_moon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mlxtend.plotting import plot_decision_regions

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.svm import SVC

# %%
x, y = make_moons(n_samples=100, noise=0.1, random_state=42)

# %%
model = SVC(kernel='rbf', C=0.5, gamma='auto')
model.fit(X, y)
# Out:
# SVC(C=0.5, gamma='auto')

# %%
def plot_decision_boundary(model, X, y):
    plt.figure(figsize=(8, 6))
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap='autumn')

    ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()

    xx = np.linspace(xlim[0], xlim[1], 100)
    yy = np.linspace(ylim[0], ylim[1], 100)
    YY, XX = np.meshgrid(yy, xx)
    xy = np.vstack([XX.ravel(), YY.ravel()]).T
    Z = model.decision_function(xy).reshape(XX.shape)

    ax.contour(XX, YY, Z, levels=[0], colors='k')  # decision boundary
    plt.title("SVM on make_moons")
    plt.show()

# %%
plot_decision_boundary(model, x, y)

# %%
plot_decision_regions(x,y, clf=model, legend=2)
# Out:
# <Axes: >
